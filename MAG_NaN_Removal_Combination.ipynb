# %%
import pandas as pd

# %%
# Defining the file path
path_to_your_file = r"/Users/arup/Documents/ISB/Datasets/MAG"

# %%
path_to_your_dataset = '/Users/arup/Documents/ISB/Datasets/MAG'

# %%
def get_nan_info(dataframe):
    # Step 1: Get columns with NaN values
    nan_columns = dataframe.columns[dataframe.isna().any()].tolist()

    # Step 2: Calculate percentage of NaN values in each column
    nan_percentage = (dataframe.isna().sum() / len(dataframe)) * 100

    # Step 3: Combine the results into a DataFrame
    nan_info = pd.DataFrame({'NaN Count': dataframe.isna().sum(), 'NaN Percentage': nan_percentage})
    nan_info = nan_info.loc[nan_info['NaN Count'] > 0]  # Filter out columns with no NaNs

    return nan_info

# %% [markdown]
# #### Loading CSV files into DataFrames
# papers_resources = pd.read_csv(path_to_your_file + "\PaperResources.csv")
# papers_0 = pd.read_csv(path_to_your_file + "\Papers_0.csv")
# papers_1 = pd.read_csv(path_to_your_file + "\Papers_1.csv")
# papers_2 = pd.read_csv(path_to_your_file + "\Papers_2.csv")
# papers_3 = pd.read_csv(path_to_your_file + "\Papers_3.csv")
# papers_4 = pd.read_csv(path_to_your_file + "\Papers_4.csv")
# papers_5 = pd.read_csv(path_to_your_file + "\Papers_5.csv")
# papers_6 = pd.read_csv(path_to_your_file + "\Papers_6.csv")
# papers_7 = pd.read_csv(path_to_your_file + "\Papers_7.csv")
# papers_8 = pd.read_csv(path_to_your_file + "\Papers_8.csv")
# papers_9 = pd.read_csv(path_to_your_file + "\Papers_9.csv")
# paper_fields_of_study_0 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudy_0.csv")
# paper_fields_of_study_1 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudy_1.csv")
# paper_fields_of_study_2 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudy_2.csv")
# paper_fields_of_study_3 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudy_3.csv")
# paper_citation_contexts = pd.read_csv(path_to_your_file + "\PaperCitationContexts.csv")
# authors_disambiguated = pd.read_csv(path_to_your_file + "\Authors_disambiguated.csv")
# paper_author_affiliations_disambiguated = pd.read_csv(path_to_your_file + "\PaperAuthorAffiliations_disambiguated.csv")
# paper_fields_of_study_labeled_1 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudyLabeled_1.csv")
# paper_fields_of_study_labeled_2 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudyLabeled_2.csv")
# paper_fields_of_study_labeled_3 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudyLabeled_3.csv")
# paper_fields_of_study_labeled_4 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudyLabeled_4.csv")
# paper_fields_of_study_labeled_5 = pd.read_csv(path_to_your_file + "\PaperFieldsOfStudyLabeled_5.csv")
# affiliations = pd.read_csv(path_to_your_file + "\Affiliations.csv")
# conference_instances = pd.read_csv(path_to_your_file + "\ConferenceInstances.csv")
# conference_series = pd.read_csv(path_to_your_file + "\ConferenceSeries.csv")
# country_annual_flows = pd.read_csv(path_to_your_file + "\CountryAnnualFlows.csv")
# entity_related_entities = pd.read_csv(path_to_your_file + "\EntityRelatedEntities.csv")
# field_of_study_children = pd.read_csv(path_to_your_file + "\FieldOfStudyChildren.csv")
# field_of_study_extended_attributes = pd.read_csv(path_to_your_file + "\FieldOfStudyExtendedAttributes.csv")
# field_of_study_labeled = pd.read_csv(path_to_your_file + "\FieldOfStudyLabeled.csv")
# fields_of_study = pd.read_csv(path_to_your_file + "\FieldsOfStudy.csv")
# journals = pd.read_csv(path_to_your_file + "\Journals.csv")
# paper_author_affiliation_disambiguated = pd.read_csv(path_to_your_file + "\PaperAuthorAffiliation_Disambiguated.csv")
# related_field_of_study = pd.read_csv(path_to_your_file + "\RelatedFieldOfStudy.csv")

# %% [markdown]
# ## MAG
#
# Columns for DataFrame: PaperResources.csv
# ['resourceType', 'fabio_hasURL', 'ownResource', 'entity_id']
#
# papers
#
# paper_fields_of_study
#
# Columns for DataFrame: PaperCitationContexts.csv
# ['entity_id', 'class', 'cito_hasCitingEntity', 'cito_hasCitedEntity']
#
#
# Columns for DataFrame: Authors_disambiguated.csv
# ['entity_id', 'class', 'rank', 'org#memberOf', 'foaf_name', 'paperCount', 'paperFamilyCount', 'citationCount']
#
#
# Columns for DataFrame: PaperAuthorAffiliations_disambiguated.csv
# ['entity_id', 'dcterms_creator']
#
# paper_fields_of_study_labeled
#
# Columns for DataFrame: Affiliations.csv
# ['entity_id', 'class', 'foaf_name', 'foundation_date', 'type_entities', 'acronym', 'pos#lat', 'pos#long', 'city_name', 'city_lat', 'city_lon', 'state_name', 'postcode', 'country_name', 'country_alpha2', 'country_alpha3', 'country_official_name', 'country_2']
#
#
# Columns for DataFrame: ConferenceInstances.csv
# ['class', 'isPartOf', 'dbpedia_loc', 'foaf_homepage', 'owl#start', 'owl#end', 'submissionDeadlineDate', 'pageCount', 'paperFamilyCount', 'citationCount', 'entity_id', 'notificationDueDate', 'finalVersionDueDate', 'abstractRegistrationDate']
#
#
# Columns for DataFrame: ConferenceSeries.csv
# ['class', 'rank', 'foaf_name', 'paperCount', 'paperFamilyCount', 'citationCount', 'entity_id']
#
#
# Columns for DataFrame: CountryAnnualFlows.csv
# ['country', '1857_out', '1857_in', '1857_ret', '1857_outNat', '1857_inNat', '1858_out', '1858_in', '1858_ret', '1858_outNat', '1858_inNat', '1862_out', '1862_in', '1862_ret', '1862_outNat', '1862_inNat', '1873_out', '1873_in', '1873_ret', '1873_outNat', '1873_inNat', '1874_out', '1874_in', '1874_ret', '1874_outNat', '1874_inNat', '1882_out', '1882_in', '1882_ret', '1882_outNat', '1882_inNat', '1896_out', '1896_in', '1896_ret', '1896_outNat', '1896_inNat', '1902_out', '1902_in', '1902_ret', '1902_outNat', '1902_inNat', '1905_out', '1905_in', '1905_ret', '1905_outNat', '1905_inNat', '1908_out', '1908_in', '1908_ret', '1908_outNat', '1908_inNat', '1918_out', '1918_in', '1918_ret', '1918_outNat', '1918_inNat', '1921_out', '1921_in', '1921_ret', '1921_outNat', '1921_inNat', '1924_out', '1924_in', '1924_ret', '1924_outNat', '1924_inNat', '1925_out', '1925_in', '1925_ret', '1925_outNat', '1925_inNat', '1926_out', '1926_in', '1926_ret', '1926_outNat', '1926_inNat', '1927_out', '1927_in', '1927_ret', '1927_outNat', '1927_inNat', '1928_out', '1928_in', '1928_ret', '1928_outNat', '1928_inNat', '1929_out', '1929_in', '1929_ret', '1929_outNat', '1929_inNat', '1931_out', '1931_in', '1931_ret', '1931_outNat', '1931_inNat', '1933_out', '1933_in', '1933_ret', '1933_outNat', '1933_inNat', '1934_out', '1934_in', '1934_ret', '1934_outNat', '1934_inNat', '1935_out', '1935_in', '1935_ret', '1935_outNat', '1935_inNat', '1936_out', '1936_in', '1936_ret', '1936_outNat', '1936_inNat', '1937_out', '1937_in', '1937_ret', '1937_outNat', '1937_inNat', '1938_out', '1938_in', '1938_ret', '1938_outNat', '1938_inNat', '1939_out', '1939_in', '1939_ret', '1939_outNat', '1939_inNat', '1940_out', '1940_in', '1940_ret', '1940_outNat', '1940_inNat', '1941_out', '1941_in', '1941_ret', '1941_outNat', '1941_inNat', '1942_out', '1942_in', '1942_ret', '1942_outNat', '1942_inNat', '1943_out', '1943_in', '1943_ret', '1943_outNat', '1943_inNat', '1945_out', '1945_in', '1945_ret', '1945_outNat', '1945_inNat', '1946_out', '1946_in', '1946_ret', '1946_outNat', '1946_inNat', '1947_out', '1947_in', '1947_ret', '1947_outNat', '1947_inNat', '1948_out', '1948_in', '1948_ret', '1948_outNat', '1948_inNat', '1949_out', '1949_in', '1949_ret', '1949_outNat', '1949_inNat', '1950_out', '1950_in', '1950_ret', '1950_outNat', '1950_inNat', '1951_out', '1951_in', '1951_ret', '1951_outNat', '1951_inNat', '1952_out', '1952_in', '1952_ret', '1952_outNat', '1952_inNat', '1953_out', '1953_in', '1953_ret', '1953_outNat', '1953_inNat', '1954_out', '1954_in', '1954_ret', '1954_outNat', '1954_inNat', '1955_out', '1955_in', '1955_ret', '1955_outNat', '1955_inNat', '1956_out', '1956_in', '1956_ret', '1956_outNat', '1956_inNat', '1957_out', '1957_in', '1957_ret', '1957_outNat', '1957_inNat', '1958_out', '1958_in', '1958_ret', '1958_outNat', '1958_inNat', '1959_out', '1959_in', '1959_ret', '1959_outNat', '1959_inNat', '1960_out', '1960_in', '1960_ret', '1960_outNat', '1960_inNat', '1961_out', '1961_in', '1961_ret', '1961_outNat', '1961_inNat', '1962_out', '1962_in', '1962_ret', '1962_outNat', '1962_inNat', '1963_out', '1963_in', '1963_ret', '1963_outNat', '1963_inNat', '1964_out', '1964_in', '1964_ret', '1964_outNat', '1964_inNat', '1965_out', '1965_in', '1965_ret', '1965_outNat', '1965_inNat', '1966_out', '1966_in', '1966_ret', '1966_outNat', '1966_inNat', '1967_out', '1967_in', '1967_ret', '1967_outNat', '1967_inNat', '1968_out', '1968_in', '1968_ret', '1968_outNat', '1968_inNat', '1969_out', '1969_in', '1969_ret', '1969_outNat', '1969_inNat', '1970_out', '1970_in', '1970_ret', '1970_outNat', '1970_inNat', '1971_out', '1971_in', '1971_ret', '1971_outNat', '1971_inNat', '1972_out', '1972_in', '1972_ret', '1972_outNat', '1972_inNat', '1973_out', '1973_in', '1973_ret', '1973_outNat', '1973_inNat', '1974_out', '1974_in', '1974_ret', '1974_outNat', '1974_inNat', '1975_out', '1975_in', '1975_ret', '1975_outNat', '1975_inNat', '1976_out', '1976_in', '1976_ret', '1976_outNat', '1976_inNat', '1977_out', '1977_in', '1977_ret', '1977_outNat', '1977_inNat', '1978_out', '1978_in', '1978_ret', '1978_outNat', '1978_inNat', '1979_out', '1979_in', '1979_ret', '1979_outNat', '1979_inNat', '1980_out', '1980_in', '1980_ret', '1980_outNat', '1980_inNat', '1981_out', '1981_in', '1981_ret', '1981_outNat', '1981_inNat', '1982_out', '1982_in', '1982_ret', '1982_outNat', '1982_inNat', '1983_out', '1983_in', '1983_ret', '1983_outNat', '1983_inNat', '1984_out', '1984_in', '1984_ret', '1984_outNat', '1984_inNat', '1985_out', '1985_in', '1985_ret', '1985_outNat', '1985_inNat', '1986_out', '1986_in', '1986_ret', '1986_outNat', '1986_inNat', '1987_out', '1987_in', '1987_ret', '1987_outNat', '1987_inNat', '1988_out', '1988_in', '1988_ret', '1988_outNat', '1988_inNat', '1989_out', '1989_in', '1989_ret', '1989_outNat', '1989_inNat', '1990_out', '1990_in', '1990_ret', '1990_outNat', '1990_inNat', '1991_out', '1991_in', '1991_ret', '1991_outNat', '1991_inNat', '1992_out', '1992_in', '1992_ret', '1992_outNat', '1992_inNat', '1993_out', '1993_in', '1993_ret', '1993_outNat', '1993_inNat', '1994_out', '1994_in', '1994_ret', '1994_outNat', '1994_inNat', '1995_out', '1995_in', '1995_ret', '1995_outNat', '1995_inNat', '1996_out', '1996_in', '1996_ret', '1996_outNat', '1996_inNat', '1997_out', '1997_in', '1997_ret', '1997_outNat', '1997_inNat', '1998_out', '1998_in', '1998_ret', '1998_outNat', '1998_inNat', '1999_out', '1999_in', '1999_ret', '1999_outNat', '1999_inNat', '2000_out', '2000_in', '2000_ret', '2000_outNat', '2000_inNat', '2001_out', '2001_in', '2001_ret', '2001_outNat', '2001_inNat', '2002_out', '2002_in', '2002_ret', '2002_outNat', '2002_inNat', '2003_out', '2003_in', '2003_ret', '2003_outNat', '2003_inNat', '2004_out', '2004_in', '2004_ret', '2004_outNat', '2004_inNat', '2005_out', '2005_in', '2005_ret', '2005_outNat', '2005_inNat', '2006_out', '2006_in', '2006_ret', '2006_outNat', '2006_inNat', '2007_out', '2007_in', '2007_ret', '2007_outNat', '2007_inNat', '2008_out', '2008_in', '2008_ret', '2008_outNat', '2008_inNat', '2009_out', '2009_in', '2009_ret', '2009_outNat', '2009_inNat', '2010_out', '2010_in', '2010_ret', '2010_outNat', '2010_inNat', '2011_out', '2011_in', '2011_ret', '2011_outNat', '2011_inNat', '2012_out', '2012_in', '2012_ret', '2012_outNat', '2012_inNat', '2013_out', '2013_in', '2013_ret', '2013_outNat', '2013_inNat', '2014_out', '2014_in', '2014_ret', '2014_outNat', '2014_inNat', '2015_out', '2015_in', '2015_ret', '2015_outNat', '2015_inNat', '2016_out', '2016_in', '2016_ret', '2016_outNat', '2016_inNat', '2017_out', '2017_in', '2017_ret', '2017_outNat', '2017_inNat', '2018_out', '2018_in', '2018_ret', '2018_outNat', '2018_inNat', '2019_out', '2019_in', '2019_ret', '2019_outNat', '2019_inNat', '2020_out', '2020_in', '2020_ret', '2020_outNat', '2020_inNat', 'out', 'in', 'ret', 'outNat', 'inNat']
#
#
# Columns for DataFrame: EntityRelatedEntities.csv
# ['entity_id', 'isRelatedto']
#
#
# Columns for DataFrame: FieldOfStudyChildren.csv
# ['entity_id', 'hasParent']
#
#
# Columns for DataFrame: FieldOfStudyExtendedAttributes.csv
# ['entity_id', 'owl#sameAs', 'seeAlso']
#
#
# Columns for DataFrame: FieldOfStudyLabeled.csv
# ['entity_id', 'fos_list']
#
#
# Columns for DataFrame: FieldsOfStudy.csv
# ['entity_id', 'class', 'foaf_name', 'rank', 'level', 'paperFamilyCount', 'citationCount', 'paperCount']
#
#
# Columns for DataFrame: Journals.csv
# ['class', 'rank', 'foaf_name', 'issn', 'foaf_homepage', 'paperCount', 'paperFamilyCount', 'citationCount', 'entity_id', 'publisher']
#
#
# Columns for DataFrame: PaperAuthorAffiliation_Disambiguated.csv
# ['paper', 'author', 'affiliation1', 'affiliation2']
#
#
# Columns for DataFrame: RelatedFieldOfStudy.csv
# ['entity_id', 'diseaseHasSymptom', 'diseaseHasMedicalTreatment', 'symptomHasDiseaseCause', 'medicalTreatmentForDiseaseCause', 'isRelatedTo', 'medicalTreatmentForSymptom', 'diseaseHasDiseaseCause']

# %%
PaperResources = pd.read_csv(path_to_your_file + "/PaperResources.csv")
PaperResources
# Out:
#     resourceType                                       fabio_hasURL  \
# 0              4  https://github.com/mateuszbuda/robustspeechrec...
# 1              1             http://basketballattention.appspot.com
# 2              4  https://github.com/gavinsimpson/8c13e3c5f905fd...
# 3              4  https://github.com/NVlabs/SPADE/blob/master/RE...
# 4              4                https://github.com/jroal/a2dpvolume
# ..           ...                                                ...
# 70             4   https://github.com/webscreens/openscreenprotocol
# 71             1         http://am.is.tuebingen.mpg.de/person/jbohg
# 72             2  https://atc1.aut.uah.es//~david//assets/datase...
# 73             4  https://github.com/VCCIV/BLVD/blob/master/READ...
# 74             1                  http://www.cs.columbia.edu/cg/ACM
#
#       ownResource   entity_id
# 0    2062164080r1  2062164080
# 1    2206427987r1  2206427987
# 2    2802275568r2  2802275568
# ...

# %%
get_nan_info(PaperResources)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
papers_0 = pd.read_csv(path_to_your_file + "/Papers_0.csv")
papers_1 = pd.read_csv(path_to_your_file + "/Papers_1.csv")
papers_2 = pd.read_csv(path_to_your_file + "/Papers_2.csv")
papers_3 = pd.read_csv(path_to_your_file + "/Papers_3.csv")
papers_4 = pd.read_csv(path_to_your_file + "/Papers_4.csv")
papers_5 = pd.read_csv(path_to_your_file + "/Papers_5.csv")
papers_6 = pd.read_csv(path_to_your_file + "/Papers_6.csv")
papers_7 = pd.read_csv(path_to_your_file + "/Papers_7.csv")
papers_8 = pd.read_csv(path_to_your_file + "/Papers_8.csv")
papers_9 = pd.read_csv(path_to_your_file + "/Papers_9.csv")

# %%
# List of DataFrames
dfs = [papers_0, papers_1, papers_2, papers_3, papers_4, papers_5, papers_6, papers_7, papers_8, papers_9]

# Perform outer join based on entity_id column
papers = pd.concat(dfs, ignore_index=True).groupby('entity_id').first().reset_index()

# Display merged DataFrame
papers
# Out:
#          entity_id  class      entity_type  appearsInJournal   rank  \
# 0            87802  Paper             None               NaN  25632
# 1           106995  Paper   PatentDocument               NaN  22514
# 2           185276  Paper             None               NaN  27286
# 3           188640  Paper   JournalArticle      1.357043e+08  31989
# 4           198536  Paper  ConferencePaper               NaN  21415
# ...            ...    ...              ...               ...    ...
# 238660  3035744829  Paper             None               NaN  24460
# 238661  3035745872  Paper             None               NaN  25078
# 238662  3035747258  Paper             None      2.734325e+09  21670
# 238663  3035755001  Paper   JournalArticle      1.346681e+08  22711
# 238664  3035758753  Paper             None               NaN  23206
#
#         estimatedCitationCount  referenceCount  appearsInConferenceSeries  \
# 0                            0               0                        NaN
# ...

# %%
get_nan_info(papers)
# Out:
#                              NaN Count  NaN Percentage
# entity_type                      90499       37.918840
# appearsInJournal                151250       63.373348
# appearsInConferenceSeries       234016       98.052081
# familyId                        235557       98.697756
# appearsInConferenceInstance     237135       99.358934
# dcterms_publisher               145580       60.997633
# prism_issueIdentifier           139526       58.461023
# prism_startingPage              116993       49.019756
# prism_volume                    135352       56.712128
# prism_endingPage                131808       55.227201
# prism_publicationDate                7        0.002933
# dbo_publisher                   205452       86.083841

# %%
papers = papers.drop(['appearsInJournal', 'appearsInConferenceSeries', 'familyId', 'appearsInConferenceInstance', 'dcterms_publisher', 'prism_issueIdentifier', 'prism_volume', 'prism_endingPage', 'dbo_publisher'], axis=1)
papers
# Out:
#          entity_id  class      entity_type   rank  estimatedCitationCount  \
# 0            87802  Paper             None  25632                       0
# 1           106995  Paper   PatentDocument  22514                       3
# 2           185276  Paper             None  27286                       0
# 3           188640  Paper   JournalArticle  31989                       0
# 4           198536  Paper  ConferencePaper  21415                       1
# ...            ...    ...              ...    ...                     ...
# 238660  3035744829  Paper             None  24460                       0
# 238661  3035745872  Paper             None  25078                       0
# 238662  3035747258  Paper             None  21670                       0
# 238663  3035755001  Paper   JournalArticle  22711                       0
# 238664  3035758753  Paper             None  23206                       0
#
#         referenceCount  citationCount dcterms_created  \
# ...

# %%
papers.to_csv(path_to_your_dataset + '/papers.csv', index=False)

# %%
paper_fields_of_study_0 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudy_0.csv")
paper_fields_of_study_1 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudy_1.csv")
paper_fields_of_study_2 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudy_2.csv")
paper_fields_of_study_3 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudy_3.csv")

# %%
# List of DataFrames
dfs = [paper_fields_of_study_0, paper_fields_of_study_1, paper_fields_of_study_2, paper_fields_of_study_3]

# Perform outer join based on entity_id column
paper_fields_of_study = pd.concat(dfs, ignore_index=True).groupby('entity_id').first().reset_index()

# Display merged DataFrame
paper_fields_of_study
# Out:
#          entity_id  fabio_hasDiscipline
# 0             1841             53553401
# 1             2123           2991803969
# 2             4271            127413603
# 3             9040            117258860
# 4            10053            153349607
# ...            ...                  ...
# 564817  3035752742            143998085
# 564818  3035755323            119857082
# 564819  3035758073             39549134
# 564820  3035761452            157172786
# 564821  3035761623           2780559512
#
# [564822 rows x 2 columns]

# %%
get_nan_info(paper_fields_of_study)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
paper_fields_of_study.to_csv(path_to_your_dataset + '/paper_fields_of_study.csv', index=False)

# %%
PaperCitationContexts = pd.read_csv(path_to_your_file + "/PaperCitationContexts.csv")
PaperCitationContexts
# Out:
#                     entity_id     class  cito_hasCitingEntity  \
# 0       2945435611-2963924144  Citation            2945435611
# 1       2059474222-2015827333  Citation            2059474222
# 2       2093285354-2146569590  Citation            2093285354
# 3       3011715571-2000312125  Citation            3011715571
# 4       2127818500-2088890614  Citation            2127818500
# ...                       ...       ...                   ...
# 161814  1971163166-2049780301  Citation            1971163166
# 161815  2085410542-2013829719  Citation            2085410542
# 161816  2116382369-2073343965  Citation            2116382369
# 161817  2061220153-1560869084  Citation            2061220153
# 161818  2516361613-1951724000  Citation            2516361613
#
#         cito_hasCitedEntity
# 0                2963924144
# 1                2015827333
# 2                2146569590
# 3                2000312125
# 4                2088890614
# ...                     ...
# ...

# %%
get_nan_info(PaperCitationContexts)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
Authors_disambiguated = pd.read_csv(path_to_your_file + "/Authors_disambiguated.csv")
Authors_disambiguated
# Out:
#          entity_id   class   rank  org#memberOf                  foaf_name  \
# 0       2707667312  Author  21013           NaN                Ben-Yuan Gu
# 1       2488541030  Author  21045           NaN               Jia Jian-guo
# 2       2735542882  Author  19066           NaN  Von Thurnher Wolfgang Loy
# 3       2141993737  Author  19430   137902535.0           Sheena M. Harris
# 4       2708286586  Author  21075           NaN                    H. Ayeb
# ...            ...     ...    ...           ...                        ...
# 151350  2615733564  Author  19211           NaN              Jack Robinson
# 151351  2664127077  Author  21075           NaN               Yun Chan Huh
# 151352  2101324225  Author  21075    20231570.0                   Jiayi Wu
# 151353  2119086371  Author  21075           NaN        Suguna Nantha Gopan
# 151354  2099105958  Author  18009     6615443.0                    L.X. Le
#
#         paperCount  paperFamilyCount  citationCount
# ...

# %%
get_nan_info(Authors_disambiguated)
# Out:
#               NaN Count  NaN Percentage
# org#memberOf     115538       76.335767

# %%
Authors_disambiguated = Authors_disambiguated.drop('org#memberOf', axis=1)
Authors_disambiguated
# Out:
#          entity_id   class   rank                  foaf_name  paperCount  \
# 0       2707667312  Author  21013                Ben-Yuan Gu           1
# 1       2488541030  Author  21045               Jia Jian-guo           1
# 2       2735542882  Author  19066  Von Thurnher Wolfgang Loy           2
# 3       2141993737  Author  19430           Sheena M. Harris           1
# 4       2708286586  Author  21075                    H. Ayeb           1
# ...            ...     ...    ...                        ...         ...
# 151350  2615733564  Author  19211              Jack Robinson           3
# 151351  2664127077  Author  21075               Yun Chan Huh           1
# 151352  2101324225  Author  21075                   Jiayi Wu           1
# 151353  2119086371  Author  21075        Suguna Nantha Gopan           1
# 151354  2099105958  Author  18009                    L.X. Le           3
#
#         paperFamilyCount  citationCount
# 0                      1              2
# ...

# %%
Authors_disambiguated.to_csv(path_to_your_dataset + "/Authors_disambiguated.csv", index=False)

# %%
PaperAuthorAffiliations_disambiguated = pd.read_csv(path_to_your_file + "/PaperAuthorAffiliations_disambiguated.csv")
PaperAuthorAffiliations_disambiguated
# Out:
#          entity_id  dcterms_creator
# 0       2248753246       2727178333
# 1       2958606040       2783513073
# 2       2086358816       2589727200
# 3       2766479288       2470438697
# 4       2420641414       2435768280
# ...            ...              ...
# 638206   808815267       2340031060
# 638207  1892600274        990605348
# 638208  2830353009       2863399913
# 638209  2333491978       2136372226
# 638210  2330579280       2668939353
#
# [638211 rows x 2 columns]

# %%
get_nan_info(PaperAuthorAffiliations_disambiguated)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
paper_fields_of_study_labeled_1 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudyLabeled_1.csv")
paper_fields_of_study_labeled_2 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudyLabeled_2.csv")
paper_fields_of_study_labeled_3 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudyLabeled_3.csv")
paper_fields_of_study_labeled_4 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudyLabeled_4.csv")
paper_fields_of_study_labeled_5 = pd.read_csv(path_to_your_file + "/PaperFieldsOfStudyLabeled_5.csv")

# %%
# List of DataFrames
dfs = [paper_fields_of_study_labeled_1, paper_fields_of_study_labeled_2, paper_fields_of_study_labeled_3, paper_fields_of_study_labeled_4, paper_fields_of_study_labeled_5]

# Perform outer join based on entity_id column
paper_fields_of_study_labeled = pd.concat(dfs, ignore_index=True).groupby('paper_id').first().reset_index()

# Display merged DataFrame
paper_fields_of_study_labeled
# Out:
#          paper_id                                           FoS_list  \
# 0           65465  3017588290,41008148,40738166,204321447,1549453...
# 1          129661  146897074,101276457,144133560,31367271,6320707...
# 2          135423            86803240,55493867,2908930004,2779502636
# 3          167474  2992089352,15744967,138496976,2992575036,29925...
# 4          173424  137836250,160234255,41008148,162500139,1549453...
# ...           ...                                                ...
# 24896  2054049732  2777444498,2776825266,153911025,2909817843,954...
# 24897  2054053104  191732599,153911025,91394840,148738053,7386963...
# 24898  2054058152  2776415932,139066938,2776151105,86492073,14107...
# 24899  2054060104                      2991971439,43617362,185592680
# 24900  2054064143  2779820397,55493867,2780035454,3020173782,2984...
#
#                                            research_area
# 0      Computer science:0.86_Philosophy:0.1_Mathemati...
# ...

# %%
get_nan_info(paper_fields_of_study_labeled)
# Out:
#                NaN Count  NaN Percentage
# research_area          8        0.032127

# %%
paper_fields_of_study_labeled.to_csv(path_to_your_dataset + "/paper_fields_of_study_labeled.csv", index=False)

# %%
Affiliations = pd.read_csv(path_to_your_file + "/Affiliations.csv")
Affiliations
# Out:
#      entity_id        class  \
# 0    150807315  Affiliation
# 1     72956036  Affiliation
# 2   1293055157  Affiliation
# 3   2799517759  Affiliation
# 4   2801343013  Affiliation
# 5   2802145325  Affiliation
# 6    110534114  Affiliation
# 7       443046  Affiliation
# 8   2800392737  Affiliation
# 9   2802607910  Affiliation
# 10    97187500  Affiliation
# 11   158871560  Affiliation
# 12   154326557  Affiliation
# 13  2802673661  Affiliation
# 14   185852735  Affiliation
# 15  1340461270  Affiliation
# 16   914246612  Affiliation
# 17  2803034837  Affiliation
# 18  2800719455  Affiliation
# 19   133085544  Affiliation
# 20    83024425  Affiliation
# 21    24143040  Affiliation
# 22  2900932345  Affiliation
# 23   153515283  Affiliation
# 24  1280447149  Affiliation
#
#                                             foaf_name  foundation_date  \
# 0                                  Guangxi University           1928.0
# ...

# %%
get_nan_info(Affiliations)
# Out:
#                        NaN Count  NaN Percentage
# foundation_date               10            40.0
# type_entities                 24            96.0
# acronym                       25           100.0
# city_lat                      22            88.0
# city_lon                      22            88.0
# postcode                       7            28.0
# country_official_name          3            12.0
# country_2                     25           100.0

# %%
Affiliations = Affiliations.drop(['type_entities', 'acronym', 'city_lat', 'city_lon', 'country_2'], axis=1)
Affiliations
# Out:
#      entity_id        class  \
# 0    150807315  Affiliation
# 1     72956036  Affiliation
# 2   1293055157  Affiliation
# 3   2799517759  Affiliation
# 4   2801343013  Affiliation
# 5   2802145325  Affiliation
# 6    110534114  Affiliation
# 7       443046  Affiliation
# 8   2800392737  Affiliation
# 9   2802607910  Affiliation
# 10    97187500  Affiliation
# 11   158871560  Affiliation
# 12   154326557  Affiliation
# 13  2802673661  Affiliation
# 14   185852735  Affiliation
# 15  1340461270  Affiliation
# 16   914246612  Affiliation
# 17  2803034837  Affiliation
# 18  2800719455  Affiliation
# 19   133085544  Affiliation
# 20    83024425  Affiliation
# 21    24143040  Affiliation
# 22  2900932345  Affiliation
# 23   153515283  Affiliation
# 24  1280447149  Affiliation
#
#                                             foaf_name  foundation_date  \
# 0                                  Guangxi University           1928.0
# ...

# %%
Affiliations.to_csv(path_to_your_dataset + "/Affiliations.csv", index=False)

# %%
ConferenceInstances = pd.read_csv(path_to_your_file + "/ConferenceInstances.csv")
ConferenceInstances
# Out:
#                  class    isPartOf           dbpedia_loc  \
# 0   ConferenceInstance  1174091362  San_Jose,_California
# 1   ConferenceInstance  2621818959  Nashville,_Tennessee
# 2   ConferenceInstance  1140348717  San_Jose,_California
# 3   ConferenceInstance  2623207248               Hsinchu
# 4   ConferenceInstance  1131534676               Nicosia
# 5   ConferenceInstance  1146687534                 Xi'an
# 6   ConferenceInstance  2898117985       New_Taipei_City
# 7   ConferenceInstance  2623423368          Philadelphia
# 8   ConferenceInstance  1198144544                 Paris
# 9   ConferenceInstance  1200222865                Vienna
# 10  ConferenceInstance  2232857946              Honolulu
# 11  ConferenceInstance  1124607213                   NaN
# 12  ConferenceInstance  2759111420         New_York_City
# 13  ConferenceInstance  2621820387  Louisville,_Kentucky
# 14  ConferenceInstance  1174403976      Orlando,_Florida
# ...

# %%
get_nan_info(ConferenceInstances)
# Out:
#                           NaN Count  NaN Percentage
# dbpedia_loc                       1            6.25
# foaf_homepage                     7           43.75
# owl#start                         3           18.75
# owl#end                           3           18.75
# submissionDeadlineDate            6           37.50
# notificationDueDate               7           43.75
# finalVersionDueDate               8           50.00
# abstractRegistrationDate         12           75.00

# %%
ConferenceInstances = ConferenceInstances.drop(['notificationDueDate', 'finalVersionDueDate', 'abstractRegistrationDate'], axis=1)
ConferenceInstances
# Out:
#                  class    isPartOf           dbpedia_loc  \
# 0   ConferenceInstance  1174091362  San_Jose,_California
# 1   ConferenceInstance  2621818959  Nashville,_Tennessee
# 2   ConferenceInstance  1140348717  San_Jose,_California
# 3   ConferenceInstance  2623207248               Hsinchu
# 4   ConferenceInstance  1131534676               Nicosia
# 5   ConferenceInstance  1146687534                 Xi'an
# 6   ConferenceInstance  2898117985       New_Taipei_City
# 7   ConferenceInstance  2623423368          Philadelphia
# 8   ConferenceInstance  1198144544                 Paris
# 9   ConferenceInstance  1200222865                Vienna
# 10  ConferenceInstance  2232857946              Honolulu
# 11  ConferenceInstance  1124607213                   NaN
# 12  ConferenceInstance  2759111420         New_York_City
# 13  ConferenceInstance  2621820387  Louisville,_Kentucky
# 14  ConferenceInstance  1174403976      Orlando,_Florida
# ...

# %%
ConferenceInstances.to_csv(path_to_your_dataset + "/ConferenceInstances.csv", index=False)

# %%
ConferenceSeries = pd.read_csv(path_to_your_file + "/ConferenceSeries.csv")
ConferenceSeries
# Out:
#               class   rank                                          foaf_name  \
# 0  ConferenceSeries  12100  International Conference for Internet Technolo...
# 1  ConferenceSeries  11793  International conference natural language proc...
# 2  ConferenceSeries  11922  International Conference on Recent Advances in...
# 3  ConferenceSeries  15297  Exploring Modeling Methods for Systems Analysi...
#
#    paperCount  paperFamilyCount  citationCount   entity_id
# 0         967               967           4457  2622156088
# 1        1621              1621           7532  2898139291
# 2        1303              1303           3187  2623575139
# 3          37                37            393  2756487522

# %%
get_nan_info(ConferenceSeries)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
CountryAnnualFlows = pd.read_csv(path_to_your_file + "/CountryAnnualFlows.csv")
CountryAnnualFlows
# Out:
# Empty DataFrame
# ...

# %%
get_nan_info(CountryAnnualFlows)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
EntityRelatedEntities = pd.read_csv(path_to_your_file + "/EntityRelatedEntities.csv")
EntityRelatedEntities
# Out:
#         entity_id  isRelatedto
# 0       172446870    122346577
# 1        40887890     24807848
# 2      2738994455   2898526102
# 3        80285584    114268679
# 4      2737929905   2764852450
# ...           ...          ...
# 12632  2764639374    207741693
# 12633  2764888795   2737064587
# 12634    53486688   1292159580
# 12635    17452528   1184914352
# 12636  2622034370     83511262
#
# [12637 rows x 2 columns]

# %%
get_nan_info(EntityRelatedEntities)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
FieldOfStudyChildren = pd.read_csv(path_to_your_file + "/FieldOfStudyChildren.csv")
FieldOfStudyChildren
# Out:
#       entity_id   hasParent
# 0    2909001998  2778837598
# 1    2909883222   509974204
# 2    2910769356  2780182102
# 3    2780680839  2779747767
# 4    2909864916  2778019345
# ..          ...         ...
# 952  2778042240   178790620
# 953    58431802   161790260
# 954  2779098060    44538786
# 955  2994382402    41895202
# 956   170077801   156306882
#
# [957 rows x 2 columns]

# %%
get_nan_info(FieldOfStudyChildren)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
FieldOfStudyExtendedAttributes = pd.read_csv(path_to_your_file + "/FieldOfStudyExtendedAttributes.csv")
FieldOfStudyExtendedAttributes
# Out:
#       entity_id                                         owl#sameAs  \
# 0    2908959513                                                NaN
# 1    2910850532     http://www.thefreedictionary.com/Cyclic+alkane
# 2    2908815675                                                NaN
# 3    2908885754                                                NaN
# 4    2909327494                                                NaN
# ..          ...                                                ...
# 657  2778821113                  http://dbpedia.org/resource/CCK-4
# 658  2775983024  http://dbpedia.org/resource/Prolymphocytic_leu...
# 659  2908539196                                                NaN
# 660  2909121400                                                NaN
# 661  2909939417                                                NaN
#
#                                                seeAlso
# 0    https://uts-ws.mln.nih.gov/rest/content/2018AA...
# ...

# %%
get_nan_info(FieldOfStudyExtendedAttributes)
# Out:
#             NaN Count  NaN Percentage
# owl#sameAs        386       58.308157

# %%
FieldOfStudyExtendedAttributes = FieldOfStudyExtendedAttributes.drop('owl#sameAs', axis=1)
FieldOfStudyExtendedAttributes
# Out:
#       entity_id                                            seeAlso
# 0    2908959513  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# 1    2910850532    https://www.thefreedictionary.com/Cyclic+alkane
# 2    2908815675  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# 3    2908885754  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# 4    2909327494  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# ..          ...                                                ...
# 657  2778821113                 http://en.wikipedia.org/wiki/CCK-4
# 658  2775983024  http://en.wikipedia.org/wiki/Prolymphocytic_le...
# 659  2908539196  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# 660  2909121400  https://uts-ws.mln.nih.gov/rest/content/2018AA...
# 661  2909939417  https://uts-ws.mln.nih.gov/rest/content/2018AA...
#
# [662 rows x 2 columns]

# %%
FieldOfStudyExtendedAttributes.to_csv(path_to_your_dataset + "/FieldOfStudyExtendedAttributes.csv", index=False)

# %%
FieldOfStudyLabeled = pd.read_csv(path_to_your_file + "/FieldOfStudyLabeled.csv")
FieldOfStudyLabeled
# Out:
#       entity_id                                           fos_list
# 0    2780317303  Biology:0.5_Geology:0.33_History:0.08_Geograph...
# 1    2909780435                                       Medicine:1.0
# 2    2908655481                                              -:0.0
# 3    3020147417                                       Medicine:1.0
# 4    2909077891                           Medicine:0.5_Biology:0.5
# ..          ...                                                ...
# 735  2909196820  Biology:0.61_Geology:0.17_Engineering:0.11_Pol...
# 736  2909417095                                              -:0.0
# 737  2911216015                                              -:0.0
# 738  2908830005                                              -:0.0
# 739  2993125946                                              -:0.0
#
# [740 rows x 2 columns]

# %%
get_nan_info(FieldOfStudyLabeled)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
FieldsOfStudy = pd.read_csv(path_to_your_file + "/FieldsOfStudy.csv")
FieldsOfStudy
# Out:
#       entity_id         class                   foaf_name   rank  level  \
# 0    2911196251  FieldOfStudy       Langford Laboratories  19886      3
# 1    2910346524  FieldOfStudy            Aedes palauensis  22082      3
# 2    2910143176  FieldOfStudy  Rhytidophyllum auriculatum  22082      3
# 3    2910506288  FieldOfStudy       Alcanivorax pacificus  20546      3
# 4    2780330018  FieldOfStudy             Brasilodontidae  21867      5
# ..          ...           ...                         ...    ...    ...
# 735  2909654463  FieldOfStudy               Glucagon Gene  17884      5
# 736  2909360478  FieldOfStudy     Candidatus Monilibacter  21389      3
# 737  2908892613  FieldOfStudy             Paracolobactrum  16270      5
# 738  2910753043  FieldOfStudy       Mycteroperca prionura  20328      3
# 739  2909680091  FieldOfStudy            Acetobacteroides  22082      3
#
#      paperFamilyCount  citationCount  paperCount
# 0                   3             17           3
# ...

# %%
get_nan_info(FieldsOfStudy)
# Out:
# Empty DataFrame
# Columns: [NaN Count, NaN Percentage]
# Index: []

# %%
Journals = pd.read_csv(path_to_your_file + "/Journals.csv")
Journals
# Out:
#       class   rank                                          foaf_name  \
# 0   Journal  12881                 Materials Research and Application
# 1   Journal  14656  Journal of Sourtheast China National Defence M...
# 2   Journal  12583                     Journal of Applied Biomedicine
# 3   Journal  13177                         Journal of clinical trials
# 4   Journal  13306                              Kyung Hee Law Journal
# 5   Journal  13468                   The Journal Orthopaedic medicine
# 6   Journal  11072                                  Marine Structures
# 7   Journal  13249  Ricerche di Pedagogia e Didattica. Journal of ...
# 8   Journal   9612                                       Algorithmica
# 9   Journal  10229                            Clinics in Perinatology
# 10  Journal   8044                      American Mathematical Monthly
# 11  Journal   9426                  Commentarii Mathematici Helvetici
# ...

# %%
get_nan_info(Journals)
# Out:
#                NaN Count  NaN Percentage
# issn                  18           37.50
# foaf_homepage         39           81.25
# publisher             48          100.00

# %%
Journals = Journals.drop(['foaf_homepage', 'publisher'], axis=1)
Journals
# Out:
#       class   rank                                          foaf_name  \
# 0   Journal  12881                 Materials Research and Application
# 1   Journal  14656  Journal of Sourtheast China National Defence M...
# 2   Journal  12583                     Journal of Applied Biomedicine
# 3   Journal  13177                         Journal of clinical trials
# 4   Journal  13306                              Kyung Hee Law Journal
# 5   Journal  13468                   The Journal Orthopaedic medicine
# 6   Journal  11072                                  Marine Structures
# 7   Journal  13249  Ricerche di Pedagogia e Didattica. Journal of ...
# 8   Journal   9612                                       Algorithmica
# 9   Journal  10229                            Clinics in Perinatology
# 10  Journal   8044                      American Mathematical Monthly
# 11  Journal   9426                  Commentarii Mathematici Helvetici
# ...

# %%
Journals.to_csv(path_to_your_dataset + "/Journals.csv", index=False)

# %%
PaperAuthorAffiliation_Disambiguated = pd.read_csv(path_to_your_file + "/PaperAuthorAffiliation_Disambiguated.csv")
PaperAuthorAffiliation_Disambiguated
# Out:
#             paper      author  affiliation1  affiliation2
# 0      2049004899  2050600857     137768463           NaN
# 1      2257220180  2115548438     110995367           NaN
# 2      1954047575   214008780      32021983           NaN
# 3      2363152908  2427528421    2799736854           NaN
# 4      2883414375  2883760195     109935558           NaN
# ...           ...         ...           ...           ...
# 77391  1980165264  2051922797     177477856           NaN
# 77392  2735870963  2734379635     931278978           NaN
# 77393  2562137911  2047667218      22759111           NaN
# 77394  1029067142  2144470725     197065608           NaN
# 77395  2525885123  2132711523     108290504           NaN
#
# [77396 rows x 4 columns]

# %%
get_nan_info(PaperAuthorAffiliation_Disambiguated)
# Out:
#               NaN Count  NaN Percentage
# affiliation2      75452       97.488242

# %%
PaperAuthorAffiliation_Disambiguated = PaperAuthorAffiliation_Disambiguated.drop('affiliation2', axis=1)
PaperAuthorAffiliation_Disambiguated
# Out:
#             paper      author  affiliation1
# 0      2049004899  2050600857     137768463
# 1      2257220180  2115548438     110995367
# 2      1954047575   214008780      32021983
# 3      2363152908  2427528421    2799736854
# 4      2883414375  2883760195     109935558
# ...           ...         ...           ...
# 77391  1980165264  2051922797     177477856
# 77392  2735870963  2734379635     931278978
# 77393  2562137911  2047667218      22759111
# 77394  1029067142  2144470725     197065608
# 77395  2525885123  2132711523     108290504
#
# [77396 rows x 3 columns]

# %%
PaperAuthorAffiliation_Disambiguated.to_csv(path_to_your_dataset + "/PaperAuthorAffiliation_Disambiguated.csv", index=False)

# %%
RelatedFieldOfStudy = pd.read_csv(path_to_your_file + "/RelatedFieldOfStudy.csv")
RelatedFieldOfStudy
# Out:
#       entity_id  diseaseHasSymptom  diseaseHasMedicalTreatment  \
# 0    2909388760                NaN                         NaN
# 1    2779319291                NaN                         NaN
# 2    2778938933                NaN                         NaN
# 3    2910483545                NaN                         NaN
# 4    2911142464                NaN                         NaN
# ..          ...                ...                         ...
# 499  2910194731                NaN                         NaN
# 500  2778846148                NaN                         NaN
# 501  2910047568                NaN                         NaN
# 502  2910794394                NaN                         NaN
# 503  2911212388                NaN                         NaN
#
#      symptomHasDiseaseCause  medicalTreatmentForDiseaseCause  isRelatedTo  \
# 0                       NaN                              NaN     42360764
# ...

# %%
get_nan_info(RelatedFieldOfStudy)
# Out:
#                                  NaN Count  NaN Percentage
# diseaseHasSymptom                      502       99.603175
# diseaseHasMedicalTreatment             504      100.000000
# symptomHasDiseaseCause                 504      100.000000
# medicalTreatmentForDiseaseCause        503       99.801587
# medicalTreatmentForSymptom             503       99.801587
# diseaseHasDiseaseCause                 503       99.801587

# %%
RelatedFieldOfStudy = RelatedFieldOfStudy.drop(['diseaseHasSymptom', 'diseaseHasMedicalTreatment', 'symptomHasDiseaseCause',  'medicalTreatmentForDiseaseCause', 'medicalTreatmentForSymptom', 'diseaseHasDiseaseCause'], axis=1)
RelatedFieldOfStudy
# Out:
#       entity_id  isRelatedTo
# 0    2909388760     42360764
# 1    2779319291    105580179
# 2    2778938933   2779622508
# 3    2910483545    168240541
# 4    2911142464   2779735863
# ..          ...          ...
# 499  2910194731      3763915
# 500  2778846148     94231801
# 501  2910047568   2522767166
# 502  2910794394    111330293
# 503  2911212388    127413603
#
# [504 rows x 2 columns]

# %%
RelatedFieldOfStudy.to_csv(path_to_your_dataset + "/RelatedFieldOfStudy.csv", index=False)
