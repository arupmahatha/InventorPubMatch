# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np

# %%
def get_nan_info(dataframe):
    # Step 1: Get columns with NaN values
    nan_columns = dataframe.columns[dataframe.isna().any()].tolist()

    # Step 2: Calculate percentage of NaN values in each column
    nan_percentage = (dataframe.isna().sum() / len(dataframe)) * 100

    # Step 3: Combine the results into a DataFrame
    nan_info = pd.DataFrame({'NaN Count': dataframe.isna().sum(), 'NaN Percentage': nan_percentage})
    nan_info = nan_info.loc[nan_info['NaN Count'] > 0]  # Filter out columns with no NaNs

    return nan_info

# %%
mag = pd.read_csv('/Users/arup/Documents/ISB/mag_final.csv')
mag
# Out:
#         entity_id                                    processed_title
# 0       566794768                   29p-aps-61 dy fe_ co_x _2の低温x線回折
# 1      2367711586  improv program evalu review techniqu base part...
# 2      2090358667    gorbachev gener secretari becom social democrat
# 3      2827751863                             speed control dc motor
# 4       596046335                              shakespear 's histori
# ...           ...                                                ...
# 16249  2062546659         coastal fring habitat threaten global warm
# 16250  2617488891  brasiguaio uma identidad na fronteira brasil/p...
# 16251  2772711505     activ torqu vector wheel drive fsae electr car
# 16252  2490723897                            technic progress evolut
# 16253  2279407042  method produc wafer compris silicon singl crys...
#
# [16254 rows x 2 columns]

# %%
patent = pd.read_csv('/Users/arup/Documents/ISB/patent_final.csv')
patent
# Out:
#        patent_id                                       patent_title  \
# 0        3969244                   Method of adsorbing heavy metals
# 1        5386430      Excimer laser processing method and apparatus
# 2        6710441  POWER SEMICONDUCTOR SWITCHING DEVICES, POWER C...
# 3        5441784                           Paper base wallcoverings
# 4        6579624  Functional film having optical and electrical ...
# ...          ...                                                ...
# 39310   10121211                   Waste analysis system and method
# 39311    6911447                      Melanocortin receptor ligands
# 39312   10240186  Devices, systems, and methods for magnetic sep...
# 39313    5974763              Cell-inside-a-cell honeycomb material
# 39314    6815399  Shear-sensitive plugging fluid for plugging an...
#
#                                     uspc_mainclass_title  \
# 0                                                    NaN
# 1                              COHERENT LIGHT GENERATORS
# 2      ACTIVE SOLID-STATE DEVICES (E.G., TRANSISTORS,...
# 3               STOCK MATERIAL OR MISCELLANEOUS ARTICLES
# 4               STOCK MATERIAL OR MISCELLANEOUS ARTICLES
# ...                                                  ...
# 39310                                                NaN
# 39311  ORGANIC COMPOUNDS -- PART OF THE CLASS 532-570...
# 39312                                                NaN
# 39313           STOCK MATERIAL OR MISCELLANEOUS ARTICLES
# 39314                  COMPOSITIONS:  COATING OR PLASTIC
#
#                                      uspc_subclass_title  \
# 0                                                    NaN
# 1                                    Excimer or exciplex
# 2      All contacts on same surface (e.g., lateral st...
# 3                                WALL AND SHELF COVERING
# 4      THREE DIMENSION IMITATION OR 'TREATED' NATURAL...
# ...                                                  ...
# 39310                                                NaN
# 39311  Quinoline or isoquinoline (including hydrogena...
# 39312                                                NaN
# 39313  Honeycomb type cells extend perpendicularly to...
# 39314                                               Slag
#
#             wipo_sector_title                    wipo_field_title  \
# 0                   Chemistry  Macromolecular chemistry, polymers
# 1      Electrical engineering             Audio-visual technology
# 2      Electrical engineering                      Semiconductors
# 3      Mechanical engineering          Textile and paper machines
# 4      Electrical engineering             Audio-visual technology
# ...                       ...                                 ...
# 39310  Electrical engineering           IT methods for management
# 39311               Chemistry                       Biotechnology
# 39312             Instruments    Analysis of biological materials
# 39313  Mechanical engineering          Textile and paper machines
# 39314            Other fields                   Civil engineering
#
#                                       processed_abstract
# 0      particul polycondens thiourea thiosemicarbazid...
# 1      excim laser ablat process form via hole resin ...
# 2      power semiconductor switch devic power convert...
# 3      invent provid paper base wallcov option decor ...
# 4      function film includ transit layer first const...
# ...                                                  ...
# 39310  embodi present invent provid techniqu identifi...
# 39311  disclos mc-3/mc-4 receptor ligand ligand follo...
# 39312  method microfluid devic instrument magnet sepa...
# 39313  honeycomb insul panel describ wherein cell pan...
# 39314  plug fluid plug subterranean format zone surro...
#
# [39315 rows x 7 columns]

# %%
# Load pre-trained sentence embeddings model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Preprocess academic titles
academic_embeddings = model.encode(mag['processed_title'])

# Batch size for processing
batch_size = 1000

# Initialize a list to store matched pairs
matched_pairs = []

# Get total number of batches
total_batches = len(patent) // batch_size + (1 if len(patent) % batch_size != 0 else 0)

# %%
# Iterate over batches of patent abstracts
for batch_idx, i in enumerate(range(0, len(patent), batch_size)):
    # Get batch of patent abstracts and corresponding IDs
    batch_patent_abstracts = patent['processed_abstract'][i:i+batch_size].tolist()
    batch_patent_ids = patent['patent_id'][i:i+batch_size].tolist()

    # Encode batch of patent abstracts
    batch_patent_embeddings = model.encode(batch_patent_abstracts)

    # Compute cosine similarity between batch of patent abstracts and academic titles
    similarities = cosine_similarity(batch_patent_embeddings, academic_embeddings)

    # Find indices with maximum similarity scores
    max_similarity_indices = np.argmax(similarities, axis=1)

    # Iterate over matched indices
    for j, idx in enumerate(max_similarity_indices):
        # Check if maximum similarity score is greater than threshold
        if similarities[j, idx] > 0.75:
            matched_pairs.append({'entity_id': mag.loc[idx, 'entity_id'], 
                                  'patent_id': batch_patent_ids[j],
                                  'academic_title': mag.loc[idx, 'processed_title'],
                                  'patent_abstract': batch_patent_abstracts[j]})
        else:
            matched_pairs.append({'entity_id': None, 
                                  'patent_id': batch_patent_ids[j],
                                  'academic_title': None,
                                  'patent_abstract': batch_patent_abstracts[j]})

    # Update progress
    tqdm.write(f"Processed batch {batch_idx + 1}/{total_batches}")
# Out:
# Processed batch 1/40
# Processed batch 2/40
# Processed batch 3/40
# Processed batch 4/40
# Processed batch 5/40
# Processed batch 6/40
# Processed batch 7/40
# Processed batch 8/40
# Processed batch 9/40
# Processed batch 10/40
# Processed batch 11/40
# Processed batch 12/40
# Processed batch 13/40
# Processed batch 14/40
# Processed batch 15/40
# Processed batch 16/40
# Processed batch 17/40
# Processed batch 18/40
# Processed batch 19/40
# Processed batch 20/40
# Processed batch 21/40
# Processed batch 22/40
# Processed batch 23/40
# Processed batch 24/40
# Processed batch 25/40
# Processed batch 26/40
# Processed batch 27/40
# Processed batch 28/40
# Processed batch 29/40
# Processed batch 30/40
# Processed batch 31/40
# Processed batch 32/40
# Processed batch 33/40
# Processed batch 34/40
# Processed batch 35/40
# Processed batch 36/40
# Processed batch 37/40
# Processed batch 38/40
# Processed batch 39/40
# Processed batch 40/40

# %%
# Create DataFrame from matched pairs
matched_pairs_df = pd.DataFrame(matched_pairs)
matched_pairs_df
# Out:
#        entity_id  patent_id academic_title  \
# 0            NaN    3969244           None
# 1            NaN    5386430           None
# 2            NaN    6710441           None
# 3            NaN    5441784           None
# 4            NaN    6579624           None
# ...          ...        ...            ...
# 39310        NaN   10121211           None
# 39311        NaN    6911447           None
# 39312        NaN   10240186           None
# 39313        NaN    5974763           None
# 39314        NaN    6815399           None
#
#                                          patent_abstract
# 0      particul polycondens thiourea thiosemicarbazid...
# 1      excim laser ablat process form via hole resin ...
# 2      power semiconductor switch devic power convert...
# 3      invent provid paper base wallcov option decor ...
# 4      function film includ transit layer first const...
# ...                                                  ...
# 39310  embodi present invent provid techniqu identifi...
# 39311  disclos mc-3/mc-4 receptor ligand ligand follo...
# 39312  method microfluid devic instrument magnet sepa...
# 39313  honeycomb insul panel describ wherein cell pan...
# 39314  plug fluid plug subterranean format zone surro...
#
# [39315 rows x 4 columns]

# %%
get_nan_info(matched_pairs_df)
# Out:
#                 NaN Count  NaN Percentage
# entity_id           39272       99.890627
# academic_title      39272       99.890627

# %%
# Create a new DataFrame with non-null values
matched_pairs_df = matched_pairs_df.dropna()
matched_pairs_df
# Out:
#           entity_id  patent_id  \
# 693    2.882301e+09   11050289
# 1525   1.983066e+09    5703076
# 2032   2.923412e+09    7416789
# 2175   1.519656e+09    6165753
# 2421   2.849586e+09   10386681
# 3949   1.983066e+09    5510349
# 4575   1.983066e+09    5510349
# 5036   1.983066e+09    5622949
# 5113   1.983066e+09    5510349
# 6492   3.978985e+07    6447716
# 7364   1.983066e+09    5703076
# 8581   2.845148e+09    5343970
# 9236   1.983066e+09    5703076
# 10041  2.612999e+09   10163324
# 10750  2.813057e+09   10802363
# 12410  2.859257e+09    6958693
# 13178  1.983066e+09    5482947
# 13894  2.957294e+09   10033041
# 14297  1.983066e+09    5620977
# 14509  1.983066e+09    5482947
# 14537  2.308314e+09    6644020
# 16720  2.595577e+09   11367866
# 18385  1.983066e+09    5475013
# 18629  2.789938e+09   10966918
# 18741  1.519656e+09    7390891
# 18931  2.877137e+09    6651614
# 19959  1.983066e+09    5703076
# 22556  2.859257e+09    6958693
# 23504  2.856950e+09    5698601
# 25924  1.983066e+09    5482947
# 27310  1.983066e+09    5614522
# 27443  1.983066e+09    5703076
# 29592  1.983066e+09    5698569
# 30484  1.983066e+09    5703076
# 31463  2.758782e+09    6958367
# 31839  1.862620e+09   11342508
# 32419  2.957294e+09   10033043
# 33779  2.859257e+09    6958693
# 34068  1.983066e+09    5482947
# 35141  2.859257e+09    6958693
# 36607  2.837277e+09   10994597
# 37927  2.827074e+09    6051037
# 38286  2.942717e+09    7484495
#
#                                           academic_title  \
# 693    power suppli control circuit power suppli cont...
# 1525   ration design potent bioavail nonpeptid cyclic...
# 2032   semiconductor integr circuit devic electron devic
# 2175           polypeptid nucleic acid molecul encod use
# 2421   liquid crystal align composit liquid crystal a...
# 3949   ration design potent bioavail nonpeptid cyclic...
# 4575   ration design potent bioavail nonpeptid cyclic...
# 5036   ration design potent bioavail nonpeptid cyclic...
# 5113   ration design potent bioavail nonpeptid cyclic...
# 6492                             core type weld electrod
# 7364   ration design potent bioavail nonpeptid cyclic...
# 8581   combin electr motor intern combust engin drive...
# 9236   ration design potent bioavail nonpeptid cyclic...
# 10041  assembl batteri monitor apparatu assembl batte...
# 10750  manufactur method devic organ thin film transi...
# 12410             imag sensor devic devic control system
# 13178  ration design potent bioavail nonpeptid cyclic...
# 13894  prepar method lithium ion batteri posit electr...
# 14297  ration design potent bioavail nonpeptid cyclic...
# 14509  ration design potent bioavail nonpeptid cyclic...
# 14537          simul admiss exhaust process diesel engin
# 16720  lithium ion batteri posit materi posit electro...
# 18385  ration design potent bioavail nonpeptid cyclic...
# 18629            topic skin formul compris plant extract
# 18741          polypeptid nucleic acid molecul encod use
# 18931  method control inake-air volum intern combust ...
# 19959  ration design potent bioavail nonpeptid cyclic...
# 22556             imag sensor devic devic control system
# 23504  method produc rigid polyurethan foam composit ...
# 25924  ration design potent bioavail nonpeptid cyclic...
# 27310  ration design potent bioavail nonpeptid cyclic...
# 27443  ration design potent bioavail nonpeptid cyclic...
# 29592  ration design potent bioavail nonpeptid cyclic...
# 30484  ration design potent bioavail nonpeptid cyclic...
# 31463                       coat composit compris starch
# 31839  organ light emit materi organ light emit devic...
# 32419  prepar method lithium ion batteri posit electr...
# 33779             imag sensor devic devic control system
# 34068  ration design potent bioavail nonpeptid cyclic...
# 35141             imag sensor devic devic control system
# 36607  batteri energi storag system integr energi typ...
# 37927  mixtur fiber-react azo dye method use dye hydr...
# 38286                 fuel injector intern combust engin
#
#                                          patent_abstract
# 693    provid power suppli circuit power suppli devic...
# 1525   urea-contain hydroxyethylamin compound effect ...
# 2032   substrat semiconductor integr circuit compon i...
# 2175   disclos nucleic acid molecul encod novel cycli...
# 2421   liquid crystal display devic contain pair subs...
# 3949   urea-contain hydroxyethylamin compound effect ...
# 4575   urea-contain hydroxyethylamin compound effect ...
# 5036   urea-contain hydroxyethylamin peptid compound ...
# 5113   urea-contain hydroxyethylamin compound effect ...
# 6492   nickel-bas alloy use weld weld method weld ele...
# 7364   urea-contain hydroxyethylamin compound effect ...
# 8581   improv hybrid electr vehicl includ intern comb...
# 9236   urea-contain hydroxyethylamin compound effect ...
# 10041  remot batteri monitor configur base upon data ...
# 10750  array substrat manufactur method thereof displ...
# 12410  sensor devic method employ provid specif senso...
# 13178  urea-contain hydroxyethylamin compound effect ...
# 13894  disclos herein artifici solid electrolyt inter...
# 14297  urea-contain hydroxyethylamin peptid compound ...
# 14509  urea-contain hydroxyethylamin compound effect ...
# 14537  invent relat method regener particul filter ex...
# 16720  porou carbon particl posit electrod activ mate...
# 18385  urea-contain hydroxyethylamin peptid compound ...
# 18629  disclos method treat skin topic skin composit ...
# 18741  disclos nucleic acid molecul encod polypeptid ...
# 18931  method oper diesel intern combust engin wherei...
# 19959  urea-contain hydroxyethylamin compound effect ...
# 22556  sensor devic method employ provid specif senso...
# 23504  complet open-cel rigid polyurethan foam produc...
# 25924  urea-contain hydroxyethylamin compound effect ...
# 27310  urea-contain hydroxyethylamin compound effect ...
# 27443  urea-contain hydroxyethylamin compound effect ...
# 29592  urea-contain hydroxyethylamin peptid compound ...
# 30484  urea-contain hydroxyethylamin compound effect ...
# 31463                              coat composit compris
# 31839         present specif relat organ light emit diod
# 32419        electrod binder lithium ion batteri compris
# 33779  sensor devic method employ provid specif senso...
# 34068  urea-contain hydroxyethylamin compound effect ...
# 35141  sensor devic method employ provid specif senso...
# 36607  energi storag system compris least one energi ...
# 37927  present invent concern dye mixtur fiber-react ...
# 38286  homogen charg compress ignit intern combust en...

# %%
matched_pairs_df.reset_index(inplace=True, drop=True)
matched_pairs_df
# Out:
#        entity_id  patent_id  \
# 0   2.882301e+09   11050289
# 1   1.983066e+09    5703076
# 2   2.923412e+09    7416789
# 3   1.519656e+09    6165753
# 4   2.849586e+09   10386681
# 5   1.983066e+09    5510349
# 6   1.983066e+09    5510349
# 7   1.983066e+09    5622949
# 8   1.983066e+09    5510349
# 9   3.978985e+07    6447716
# 10  1.983066e+09    5703076
# 11  2.845148e+09    5343970
# 12  1.983066e+09    5703076
# 13  2.612999e+09   10163324
# 14  2.813057e+09   10802363
# 15  2.859257e+09    6958693
# 16  1.983066e+09    5482947
# 17  2.957294e+09   10033041
# 18  1.983066e+09    5620977
# 19  1.983066e+09    5482947
# 20  2.308314e+09    6644020
# 21  2.595577e+09   11367866
# 22  1.983066e+09    5475013
# 23  2.789938e+09   10966918
# 24  1.519656e+09    7390891
# 25  2.877137e+09    6651614
# 26  1.983066e+09    5703076
# 27  2.859257e+09    6958693
# 28  2.856950e+09    5698601
# 29  1.983066e+09    5482947
# 30  1.983066e+09    5614522
# 31  1.983066e+09    5703076
# 32  1.983066e+09    5698569
# 33  1.983066e+09    5703076
# 34  2.758782e+09    6958367
# 35  1.862620e+09   11342508
# 36  2.957294e+09   10033043
# 37  2.859257e+09    6958693
# 38  1.983066e+09    5482947
# 39  2.859257e+09    6958693
# 40  2.837277e+09   10994597
# 41  2.827074e+09    6051037
# 42  2.942717e+09    7484495
#
#                                        academic_title  \
# 0   power suppli control circuit power suppli cont...
# 1   ration design potent bioavail nonpeptid cyclic...
# 2   semiconductor integr circuit devic electron devic
# 3           polypeptid nucleic acid molecul encod use
# 4   liquid crystal align composit liquid crystal a...
# 5   ration design potent bioavail nonpeptid cyclic...
# 6   ration design potent bioavail nonpeptid cyclic...
# 7   ration design potent bioavail nonpeptid cyclic...
# 8   ration design potent bioavail nonpeptid cyclic...
# 9                             core type weld electrod
# 10  ration design potent bioavail nonpeptid cyclic...
# 11  combin electr motor intern combust engin drive...
# 12  ration design potent bioavail nonpeptid cyclic...
# 13  assembl batteri monitor apparatu assembl batte...
# 14  manufactur method devic organ thin film transi...
# 15             imag sensor devic devic control system
# 16  ration design potent bioavail nonpeptid cyclic...
# 17  prepar method lithium ion batteri posit electr...
# 18  ration design potent bioavail nonpeptid cyclic...
# 19  ration design potent bioavail nonpeptid cyclic...
# 20          simul admiss exhaust process diesel engin
# 21  lithium ion batteri posit materi posit electro...
# 22  ration design potent bioavail nonpeptid cyclic...
# 23            topic skin formul compris plant extract
# 24          polypeptid nucleic acid molecul encod use
# 25  method control inake-air volum intern combust ...
# 26  ration design potent bioavail nonpeptid cyclic...
# 27             imag sensor devic devic control system
# 28  method produc rigid polyurethan foam composit ...
# 29  ration design potent bioavail nonpeptid cyclic...
# 30  ration design potent bioavail nonpeptid cyclic...
# 31  ration design potent bioavail nonpeptid cyclic...
# 32  ration design potent bioavail nonpeptid cyclic...
# 33  ration design potent bioavail nonpeptid cyclic...
# 34                       coat composit compris starch
# 35  organ light emit materi organ light emit devic...
# 36  prepar method lithium ion batteri posit electr...
# 37             imag sensor devic devic control system
# 38  ration design potent bioavail nonpeptid cyclic...
# 39             imag sensor devic devic control system
# 40  batteri energi storag system integr energi typ...
# 41  mixtur fiber-react azo dye method use dye hydr...
# 42                 fuel injector intern combust engin
#
#                                       patent_abstract
# 0   provid power suppli circuit power suppli devic...
# 1   urea-contain hydroxyethylamin compound effect ...
# 2   substrat semiconductor integr circuit compon i...
# 3   disclos nucleic acid molecul encod novel cycli...
# 4   liquid crystal display devic contain pair subs...
# 5   urea-contain hydroxyethylamin compound effect ...
# 6   urea-contain hydroxyethylamin compound effect ...
# 7   urea-contain hydroxyethylamin peptid compound ...
# 8   urea-contain hydroxyethylamin compound effect ...
# 9   nickel-bas alloy use weld weld method weld ele...
# 10  urea-contain hydroxyethylamin compound effect ...
# 11  improv hybrid electr vehicl includ intern comb...
# 12  urea-contain hydroxyethylamin compound effect ...
# 13  remot batteri monitor configur base upon data ...
# 14  array substrat manufactur method thereof displ...
# 15  sensor devic method employ provid specif senso...
# 16  urea-contain hydroxyethylamin compound effect ...
# 17  disclos herein artifici solid electrolyt inter...
# 18  urea-contain hydroxyethylamin peptid compound ...
# 19  urea-contain hydroxyethylamin compound effect ...
# 20  invent relat method regener particul filter ex...
# 21  porou carbon particl posit electrod activ mate...
# 22  urea-contain hydroxyethylamin peptid compound ...
# 23  disclos method treat skin topic skin composit ...
# 24  disclos nucleic acid molecul encod polypeptid ...
# 25  method oper diesel intern combust engin wherei...
# 26  urea-contain hydroxyethylamin compound effect ...
# 27  sensor devic method employ provid specif senso...
# 28  complet open-cel rigid polyurethan foam produc...
# 29  urea-contain hydroxyethylamin compound effect ...
# 30  urea-contain hydroxyethylamin compound effect ...
# 31  urea-contain hydroxyethylamin compound effect ...
# 32  urea-contain hydroxyethylamin peptid compound ...
# 33  urea-contain hydroxyethylamin compound effect ...
# 34                              coat composit compris
# 35         present specif relat organ light emit diod
# 36        electrod binder lithium ion batteri compris
# 37  sensor devic method employ provid specif senso...
# 38  urea-contain hydroxyethylamin compound effect ...
# 39  sensor devic method employ provid specif senso...
# 40  energi storag system compris least one energi ...
# 41  present invent concern dye mixtur fiber-react ...
# 42  homogen charg compress ignit intern combust en...

# %%
# Group by entity_id and aggregate other columns
aggregated_df = matched_pairs_df.groupby('entity_id').agg({
    'patent_id': lambda x: ', '.join(map(str, x)),
    'academic_title': 'first',  # Take the first value since they are related
    'patent_abstract': lambda x: ', '.join(map(str, x))
}).reset_index()

aggregated_df
# Out:
#        entity_id                                          patent_id  \
# 0   3.978985e+07                                            6447716
# 1   1.519656e+09                                   6165753, 7390891
# 2   1.862620e+09                                           11342508
# 3   1.983066e+09  5703076, 5510349, 5510349, 5622949, 5510349, 5...
# 4   2.308314e+09                                            6644020
# 5   2.595577e+09                                           11367866
# 6   2.612999e+09                                           10163324
# 7   2.758782e+09                                            6958367
# 8   2.789938e+09                                           10966918
# 9   2.813057e+09                                           10802363
# 10  2.827074e+09                                            6051037
# 11  2.837277e+09                                           10994597
# 12  2.845148e+09                                            5343970
# 13  2.849586e+09                                           10386681
# 14  2.856950e+09                                            5698601
# 15  2.859257e+09                 6958693, 6958693, 6958693, 6958693
# 16  2.877137e+09                                            6651614
# 17  2.882301e+09                                           11050289
# 18  2.923412e+09                                            7416789
# 19  2.942717e+09                                            7484495
# 20  2.957294e+09                                 10033041, 10033043
#
#                                        academic_title  \
# 0                             core type weld electrod
# 1           polypeptid nucleic acid molecul encod use
# 2   organ light emit materi organ light emit devic...
# 3   ration design potent bioavail nonpeptid cyclic...
# 4           simul admiss exhaust process diesel engin
# 5   lithium ion batteri posit materi posit electro...
# 6   assembl batteri monitor apparatu assembl batte...
# 7                        coat composit compris starch
# 8             topic skin formul compris plant extract
# 9   manufactur method devic organ thin film transi...
# 10  mixtur fiber-react azo dye method use dye hydr...
# 11  batteri energi storag system integr energi typ...
# 12  combin electr motor intern combust engin drive...
# 13  liquid crystal align composit liquid crystal a...
# 14  method produc rigid polyurethan foam composit ...
# 15             imag sensor devic devic control system
# 16  method control inake-air volum intern combust ...
# 17  power suppli control circuit power suppli cont...
# 18  semiconductor integr circuit devic electron devic
# 19                 fuel injector intern combust engin
# 20  prepar method lithium ion batteri posit electr...
#
#                                       patent_abstract
# 0   nickel-bas alloy use weld weld method weld ele...
# 1   disclos nucleic acid molecul encod novel cycli...
# 2          present specif relat organ light emit diod
# 3   urea-contain hydroxyethylamin compound effect ...
# 4   invent relat method regener particul filter ex...
# 5   porou carbon particl posit electrod activ mate...
# 6   remot batteri monitor configur base upon data ...
# 7                               coat composit compris
# 8   disclos method treat skin topic skin composit ...
# 9   array substrat manufactur method thereof displ...
# 10  present invent concern dye mixtur fiber-react ...
# 11  energi storag system compris least one energi ...
# 12  improv hybrid electr vehicl includ intern comb...
# 13  liquid crystal display devic contain pair subs...
# 14  complet open-cel rigid polyurethan foam produc...
# 15  sensor devic method employ provid specif senso...
# 16  method oper diesel intern combust engin wherei...
# 17  provid power suppli circuit power suppli devic...
# 18  substrat semiconductor integr circuit compon i...
# 19  homogen charg compress ignit intern combust en...
# 20  disclos herein artifici solid electrolyt inter...

# %%
# Save the aggregated DataFrame to a new CSV file
aggregated_df.to_csv('aggregated_csv_file.csv', index=False)
